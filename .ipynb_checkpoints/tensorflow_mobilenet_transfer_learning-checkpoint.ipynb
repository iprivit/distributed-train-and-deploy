# %% [markdown]
# ## Welcome to the Tensorflow Mobilenet transfer learning workshop!
# ### Here we are going to learn how to take a pretrained Mobilenet V2 from Keras and use transfer learning to apply it to a new dataset.

# %%
# !pip install tqdm
# !pip install sagemaker-experiments
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (4.46.0)
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: sagemaker-experiments in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.1.13)
# Requirement already satisfied: boto3>=1.12.8 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from sagemaker-experiments) (1.12.39)
# Requirement already satisfied: botocore<1.16.0,>=1.15.39 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.12.8->sagemaker-experiments) (1.15.39)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.12.8->sagemaker-experiments) (0.9.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.12.8->sagemaker-experiments) (0.3.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.12.8->sagemaker-experiments) (0.14)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.12.8->sagemaker-experiments) (1.23)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.12.8->sagemaker-experiments) (2.7.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.16.0,>=1.15.39->boto3>=1.12.8->sagemaker-experiments) (1.11.0)
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %pylab inline
import boto3, re, os
import sagemaker
from sagemaker import get_execution_role
from sagemaker.tensorflow import TensorFlow
from smexperiments.experiment import Experiment
from smexperiments.tracker import Tracker
from smexperiments.trial import Trial
import tarfile
import tensorflow as tf
from glob import glob
import numpy as np
import subprocess
from tqdm import tqdm
import cv2

role = get_execution_role()
sess = sagemaker.Session()
bucket = sess.default_bucket()
sage = boto3.client('sagemaker')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.

# %% [markdown]
# Let's first download the data, we are going to be working with the Caltech256 dataset

# %%
# !wget http://www.vision.caltech.edu/Image_Datasets/Caltech256/256_ObjectCategories.tar .
# !tar -xvf 256_ObjectCategories.tar

# %% [markdown]
# Unfortunately, if we want to use multiple GPUs in Keras, currently we cannot simply access images from a directory, we instead need our images to be in the format of a Numpy array.

# %%
categories = {}
folders = os.listdir('256_ObjectCategories/')
folders.sort()
for d in folders:
    files = glob(f'256_ObjectCategories/{d}/*.jpg')
    files.sort()
    categories[d] = files
    
# since there are not the same amount of images for each category we are going to want to even them out.
ls = []
for cat in categories:
    l = len(categories[cat])
    ls.append(l)
    
examples = min(ls)
ex_ind = np.argmin(ls)
print(f'Minimum number of examples is {examples}')
# Out:
# Minimum number of examples is 80

# %% [markdown]
# We will load our images using OpenCV, these specific images are in RBG format, so in order to

# %%
imgs = []
labs = []

for j,cat in tqdm(enumerate(categories)):
    for i,file in enumerate(categories[cat]):
        img = cv2.imread(file)
        img = cv2.resize(img, (224,224))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        imgs.append(np.array(img))
        labs.append(j)

img_arr = np.array(imgs) # , dtype=np.float32
labels = tf.keras.utils.to_categorical(labs)
del imgs, labs
# Out:
# 257it [00:57,  4.46it/s]

# %% [markdown]
# Let's take a look at one of the images

# %%
plt.figure(figsize=(14,7))
plt.imshow(img_arr[98])

# %% [markdown]
# Let's split our data into train and test sets

# %%
split = .8
inds = np.arange(img_arr.shape[0])
np.random.shuffle(inds)
train_x = img_arr[:(int(inds.shape[0]*split))]
train_y = labels[:(int(inds.shape[0]*split))]
test_x = img_arr[(int(inds.shape[0]*split)):]
test_y = labels[(int(inds.shape[0]*split)):]

# %% [markdown]
# Now we need to save our data and move it to s3 so that your model can access it.

# %%
# !mkdir data

np.save('data/train_data.npy',train_x)
np.save('data/train_labels.npy',train_y)
np.save('data/eval_data.npy',test_x)
np.save('data/eval_labels.npy',test_y)
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %% [markdown]
# For simplicity we can just download the data from this s3 bucket:

# %%
# !mkdir data

# !wget https://caltech256-bucket.s3.amazonaws.com/train_data.npy -P data
# !wget https://caltech256-bucket.s3.amazonaws.com/eval_data.npy -P data
# !wget https://caltech256-bucket.s3.amazonaws.com/train_labels.npy -P data
# !wget https://caltech256-bucket.s3.amazonaws.com/eval_labels.npy -P data
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.
# --2020-05-06 13:05:41--  https://caltech256-bucket.s3.amazonaws.com/train_data.npy
# Resolving caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)... 52.216.129.99
# Connecting to caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)|52.216.129.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3685678208 (3.4G) [application/x-www-form-urlencoded]
# Saving to: ‘train_data.npy’
#
# train_data.npy      100%[===================>]   3.43G  71.2MB/s    in 54s
#
# 2020-05-06 13:06:36 (64.9 MB/s) - ‘train_data.npy’ saved [3685678208/3685678208]
#
# --2020-05-06 13:06:36--  http://data/
# Resolving data (data)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘data’
# FINISHED --2020-05-06 13:06:36--
# Total wall clock time: 54s
# Downloaded: 1 files, 3.4G in 54s (64.9 MB/s)
# --2020-05-06 13:06:36--  https://caltech256-bucket.s3.amazonaws.com/eval_data.npy
# Resolving caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)... 52.216.27.156
# Connecting to caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)|52.216.27.156|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 921532544 (879M) [application/x-www-form-urlencoded]
# Saving to: ‘eval_data.npy’
#
# eval_data.npy       100%[===================>] 878.84M  68.7MB/s    in 14s
#
# 2020-05-06 13:06:50 (63.3 MB/s) - ‘eval_data.npy’ saved [921532544/921532544]
#
# --2020-05-06 13:06:50--  http://data/
# Resolving data (data)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘data’
# FINISHED --2020-05-06 13:06:50--
# Total wall clock time: 14s
# Downloaded: 1 files, 879M in 14s (63.3 MB/s)
# --2020-05-06 13:06:50--  https://caltech256-bucket.s3.amazonaws.com/train_labels.npy
# Resolving caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)... 52.216.99.83
# Connecting to caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)|52.216.99.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25170708 (24M) [application/x-www-form-urlencoded]
# Saving to: ‘train_labels.npy’
#
# train_labels.npy    100%[===================>]  24.00M  60.1MB/s    in 0.4s
#
# 2020-05-06 13:06:51 (60.1 MB/s) - ‘train_labels.npy’ saved [25170708/25170708]
#
# --2020-05-06 13:06:51--  http://data/
# Resolving data (data)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘data’
# FINISHED --2020-05-06 13:06:51--
# Total wall clock time: 0.5s
# Downloaded: 1 files, 24M in 0.4s (60.1 MB/s)
# --2020-05-06 13:06:51--  https://caltech256-bucket.s3.amazonaws.com/eval_labels.npy
# Resolving caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)... 52.216.145.139
# Connecting to caltech256-bucket.s3.amazonaws.com (caltech256-bucket.s3.amazonaws.com)|52.216.145.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6293544 (6.0M) [binary/octet-stream]
# Saving to: ‘eval_labels.npy’
#
# eval_labels.npy     100%[===================>]   6.00M  --.-KB/s    in 0.07s
#
# 2020-05-06 13:06:51 (87.9 MB/s) - ‘eval_labels.npy’ saved [6293544/6293544]
#
# --2020-05-06 13:06:51--  http://data/
# Resolving data (data)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘data’
# FINISHED --2020-05-06 13:06:51--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 6.0M in 0.07s (87.9 MB/s)

# %%
# !aws s3 cp --recursive data s3://$bucket/caltech256
# Out:
# upload: data/eval_labels.npy to s3://sagemaker-us-east-1-209419068016/caltech256/eval_labels.npy
# upload: data/train_labels.npy to s3://sagemaker-us-east-1-209419068016/caltech256/train_labels.npy
# upload: data/eval_data.npy to s3://sagemaker-us-east-1-209419068016/caltech256/eval_data.npy
# upload: data/train_data.npy to s3://sagemaker-us-east-1-209419068016/caltech256/train_data.npy

# %%
training_data_uri = f's3://{bucket}/caltech256/'
output_uri = f's3://{bucket}/mobilenet/'

mobile_experiment = Experiment.create(
    experiment_name="mobilenet-tf-caltech256-classification1", 
    description="Finetune mobilenet on caltech256", 
    sagemaker_boto_client=sage)

with Tracker.create(display_name="Preprocessing", sagemaker_boto_client=sage) as tracker:
     tracker.log_input(name="caltech-dataset", media_type="s3/uri", value=training_data_uri)

# %% [markdown]
# Here we specify our estimator and training script that will get executed on a training instance. We can specify the type of instances and number of instances to run training on when we specify our estimator. Let's take a look at mobile_keras.py.

# %%
hyperparameters = {'epochs':4, 'lr':.0001, 'batch_size':512}

for i, script in enumerate(['mobile-keras', 'mobile-keras-addl-layer']):
    trial_name = f"cnn-training-job-{script}-hidden-channels-{int(time.time())}"
    cnn_trial = Trial.create(
        trial_name=trial_name, 
        experiment_name=mobile_experiment.experiment_name,
        sagemaker_boto_client=sage,
    )
    cnn_trial.add_trial_component(tracker.trial_component)
    mobile_estimator = TensorFlow(
                          entry_point=f'{script}.py', # this points to the script that will execute training
                          model_dir=output_uri, # where the model will eventually be saved
                         role=role,
                         train_instance_count=1, 
                         train_instance_type='ml.p3.8xlarge',
                         framework_version='2.1',
                         py_version='py3',
                        hyperparameters=hyperparameters,
                          script_mode=True,
                         distributions={'parameter_server': {'enabled': True}},
                        metric_definitions=[
                            {'Name':'train:loss', 'Regex':'Train Loss: (.*?);'},
                            {'Name':'test:loss', 'Regex':'Test Average loss: (.*?),'},
                            {'Name':'test:accuracy', 'Regex':'Test Accuracy: (.*?)%;'}
                        ],
    ) #,
    
    cnn_training_job_name = "cnn-training-job-{}".format(int(time.time()))
    
    mobile_estimator.fit(
        inputs={'training': training_data_uri}, 
        job_name=cnn_training_job_name,
        experiment_config={
            "ExperimentName": mobile_experiment.experiment_name, 
            "TrialName": cnn_trial.trial_name,
            "TrialComponentDisplayName": "Training",
        }
    )
# Out:
# WARNING:sagemaker:You have selected a multi-GPU training instance type. You have also enabled parameter server for distributed training. Distributed training with the default parameter server configuration will not fully leverage all GPU cores; the parameter server will be configured to run only one worker per host regardless of the number of GPUs.
# INFO:sagemaker:Amazon SageMaker Debugger does not currently support Parameter Server distribution
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1588775704
# 2020-05-06 14:35:05 Starting - Starting the training job...
# 2020-05-06 14:35:07 Starting - Launching requested ML instances......
# 2020-05-06 14:36:13 Starting - Preparing the instances for training......
# 2020-05-06 14:37:23 Downloading - Downloading input data.........
# 2020-05-06 14:39:00 Training - Downloading the training image...
# 2020-05-06 14:39:21 Training - Training image download completed. Training in progress.2020-05-06 14:39:24,359 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-05-06 14:39:24,832 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 512,
#         "lr": 0.0001,
#         "model_dir": "s3://sagemaker-us-east-1-209419068016/mobilenet/",
#         "epochs": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1588775704",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-209419068016/cnn-training-job-1588775704/source/sourcedir.tar.gz",
#     "module_name": "mobile-keras",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mobile-keras.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":512,"epochs":4,"lr":0.0001,"model_dir":"s3://sagemaker-us-east-1-209419068016/mobilenet/"}
# SM_USER_ENTRY_POINT=mobile-keras.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mobile-keras
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-209419068016/cnn-training-job-1588775704/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":512,"epochs":4,"lr":0.0001,"model_dir":"s3://sagemaker-us-east-1-209419068016/mobilenet/"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1588775704","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-209419068016/cnn-training-job-1588775704/source/sourcedir.tar.gz","module_name":"mobile-keras","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mobile-keras.py"}
# SM_USER_ARGS=["--batch_size","512","--epochs","4","--lr","0.0001","--model_dir","s3://sagemaker-us-east-1-209419068016/mobilenet/"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=512
# SM_HP_LR=0.0001
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-209419068016/mobilenet/
# SM_HP_EPOCHS=4
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mobile-keras.py --batch_size 512 --epochs 4 --lr 0.0001 --model_dir s3://sagemaker-us-east-1-209419068016/mobilenet/
#
#
# /usr/local/lib/python3.6/dist-packages/keras_applications/mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# #015   8192/9406464 [..............................] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0156610944/9406464 [====================>.........] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0159412608/9406464 [==============================] - 0s 0us/step
# Train on 24485 samples, validate on 6122 samples
# Epoch 1/4
# INFO:tensorflow:batch_all_reduce: 2 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# INFO:tensorflow:batch_all_reduce: 2 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# INFO:tensorflow:batch_all_reduce: 2 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# INFO:tensorflow:batch_all_reduce: 2 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# ip-10-2-114-98:51:198 [3] NCCL INFO NET/Socket : Using [0]ecs-eth0:169.254.172.3<0> [1]eth0:10.2.114.98<0>
# ip-10-2-114-98:51:198 [3] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
#
# ip-10-2-114-98:51:198 [3] external/nccl_archive/src/misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# NCCL version 2.4.7+cudaCUDA_MAJOR.CUDA_MINOR
# ip-10-2-114-98:51:268 [1] NCCL INFO Setting affinity for GPU 1 to ffffffff
# ip-10-2-114-98:51:270 [3] NCCL INFO Setting affinity for GPU 3 to ffffffff
# ip-10-2-114-98:51:269 [2] NCCL INFO Setting affinity for GPU 2 to ffffffff
# ip-10-2-114-98:51:267 [0] NCCL INFO Setting affinity for GPU 0 to ffffffff
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 00 :    0   1   2   3
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 01 :    0   2   1   3
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 02 :    0   3   1   2
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 03 :    0   3   2   1
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 04 :    0   1   2   3
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 05 :    0   2   1   3
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 06 :    0   3   1   2
# ip-10-2-114-98:51:267 [0] NCCL INFO Channel 07 :    0   3   2   1
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 00 : 0[0] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 00 : 1[1] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 00 : 3[3] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 00 : 2[2] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 01 : 1[1] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 01 : 0[0] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 01 : 3[3] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 01 : 2[2] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 02 : 1[1] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 02 : 0[0] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 02 : 3[3] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 02 : 2[2] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 03 : 1[1] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 03 : 0[0] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 03 : 2[2] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 03 : 3[3] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 04 : 0[0] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 04 : 1[1] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 04 : 3[3] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 04 : 2[2] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 05 : 1[1] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 05 : 0[0] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 05 : 3[3] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 05 : 2[2] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 06 : 0[0] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 06 : 1[1] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 06 : 2[2] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 06 : 3[3] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:268 [1] NCCL INFO Ring 07 : 1[1] -> 0[0] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Ring 07 : 0[0] -> 3[3] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO Using 256 threads, Min Comp Cap 7, Trees disabled
# ip-10-2-114-98:51:270 [3] NCCL INFO Ring 07 : 3[3] -> 2[2] via P2P/direct pointer
# ip-10-2-114-98:51:269 [2] NCCL INFO Ring 07 : 2[2] -> 1[1] via P2P/direct pointer
# ip-10-2-114-98:51:267 [0] NCCL INFO comm 0x7fa8a0007080 rank 0 nranks 4 cudaDev 0 nvmlDev 0 - Init COMPLETE
# ip-10-2-114-98:51:270 [3] NCCL INFO comm 0x7fa88c006a40 rank 3 nranks 4 cudaDev 3 nvmlDev 3 - Init COMPLETE
# ip-10-2-114-98:51:269 [2] NCCL INFO comm 0x7fa898006a40 rank 2 nranks 4 cudaDev 2 nvmlDev 2 - Init COMPLETE
# ip-10-2-114-98:51:268 [1] NCCL INFO comm 0x7fa894007790 rank 1 nranks 4 cudaDev 1 nvmlDev 1 - Init COMPLETE
# ip-10-2-114-98:51:262 [0] NCCL INFO Launch mode Group/CGMD
# #015  512/24485 [..............................] - ETA: 29:12 - loss: 5.5491 - accuracy: 0.0059#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1024/24485 [>.............................] - ETA: 14:19 - loss: 5.5492 - accuracy: 0.0029#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/24485 [>.............................] - ETA: 9:21 - loss: 5.5491 - accuracy: 0.0026 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2048/24485 [=>............................] - ETA: 6:52 - loss: 5.5492 - accuracy: 0.0024#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2560/24485 [==>...........................] - ETA: 5:23 - loss: 5.5491 - accuracy: 0.0023#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3072/24485 [==>...........................] - ETA: 4:24 - loss: 5.5491 - accuracy: 0.0023#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/24485 [===>..........................] - ETA: 3:41 - loss: 5.5491 - accuracy: 0.0020#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4096/24485 [====>.........................] - ETA: 3:09 - loss: 5.5490 - accuracy: 0.0022#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4608/24485 [====>.........................] - ETA: 2:44 - loss: 5.5489 - accuracy: 0.0030#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01 ...
# Epoch 2/4
# #015  512/24485 [..............................] - ETA: 4s - loss: 5.5389 - accuracy: 0.0488#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1024/24485 [>.............................] - ETA: 4s - loss: 5.5384 - accuracy: 0.0488#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/24485 [>.............................] - ETA: 4s - loss: 5.5375 - accuracy: 0.0488#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2048/24485 [=>............................] - ETA: 3s - loss: 5.5369 - accuracy: 0.0474#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2560/24485 [==>...........................] - ETA: 3s - loss: 5.5365 - accuracy: 0.0477#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3072/24485 [==>...........................] - ETA: 3s - loss: 5.5369 - accuracy: 0.0456#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/24485 [===>..........................] - ETA: 3s - loss: 5.5368 - accuracy: 0.0455#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4096/24485 [====>.........................] - ETA: 3s - loss: 5.5366 - accuracy: 0.0449#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4608/24485 [====>.........................] - ETA: 3s - loss: 5.5367 - accuracy: 0.0432#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 ...
# Epoch 3/4
# #015  512/24485 [..............................] - ETA: 4s - loss: 5.5105 - accuracy: 0.0488#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1024/24485 [>.............................] - ETA: 4s - loss: 5.5088 - accuracy: 0.0547#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/24485 [>.............................] - ETA: 4s - loss: 5.5070 - accuracy: 0.0599#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2048/24485 [=>............................] - ETA: 3s - loss: 5.5037 - accuracy: 0.0635#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2560/24485 [==>...........................] - ETA: 3s - loss: 5.5044 - accuracy: 0.0621#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3072/24485 [==>...........................] - ETA: 3s - loss: 5.5041 - accuracy: 0.0622#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/24485 [===>..........................] - ETA: 3s - loss: 5.5038 - accuracy: 0.0628#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4096/24485 [====>.........................] - ETA: 3s - loss: 5.5043 - accuracy: 0.0615#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4608/24485 [====>.........................] - ETA: 3s - loss: 5.5051 - accuracy: 0.0608#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 ...
# Epoch 4/4
# #015  512/24485 [..............................] - ETA: 4s - loss: 5.4658 - accuracy: 0.1816#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1024/24485 [>.............................] - ETA: 3s - loss: 5.4697 - accuracy: 0.1699#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/24485 [>.............................] - ETA: 3s - loss: 5.4632 - accuracy: 0.1790#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2048/24485 [=>............................] - ETA: 3s - loss: 5.4591 - accuracy: 0.1870#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2560/24485 [==>...........................] - ETA: 3s - loss: 5.4577 - accuracy: 0.1883#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3072/24485 [==>...........................] - ETA: 3s - loss: 5.4549 - accuracy: 0.1943#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/24485 [===>..........................] - ETA: 3s - loss: 5.4521 - accuracy: 0.1989#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4096/24485 [====>.........................] - ETA: 3s - loss: 5.4514 - accuracy: 0.1992#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4608/24485 [====>.........................] - ETA: 3s - loss: 5.4509 - accuracy: 0.2018#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 ...
# 2020-05-06 14:42:03.149187: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# 2020-05-06 14:42:13,653 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-05-06 14:42:23 Uploading - Uploading generated training model
# 2020-05-06 14:42:23 Completed - Training job completed
# WARNING:sagemaker:You have selected a multi-GPU training instance type. You have also enabled parameter server for distributed training. Distributed training with the default parameter server configuration will not fully leverage all GPU cores; the parameter server will be configured to run only one worker per host regardless of the number of GPUs.
# Training seconds: 300
# Billable seconds: 300
# INFO:sagemaker:Amazon SageMaker Debugger does not currently support Parameter Server distribution
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1588776170
# 2020-05-06 14:42:50 Starting - Starting the training job...
# 2020-05-06 14:42:53 Starting - Launching requested ML instances......
# 2020-05-06 14:43:59 Starting - Preparing the instances for training......
# 2020-05-06 14:45:05 Downloading - Downloading input data.........
# 2020-05-06 14:46:41 Training - Downloading the training image...
# 2020-05-06 14:47:02 Training - Training image download completed. Training in progress.2020-05-06 14:47:06,239 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-05-06 14:47:06,779 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 512,
#         "lr": 0.0001,
#         "model_dir": "s3://sagemaker-us-east-1-209419068016/mobilenet/",
#         "epochs": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1588776170",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-209419068016/cnn-training-job-1588776170/source/sourcedir.tar.gz",
#     "module_name": "mobile-keras-addl-layer",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mobile-keras-addl-layer.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":512,"epochs":4,"lr":0.0001,"model_dir":"s3://sagemaker-us-east-1-209419068016/mobilenet/"}
# SM_USER_ENTRY_POINT=mobile-keras-addl-layer.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mobile-keras-addl-layer
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-209419068016/cnn-training-job-1588776170/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":512,"epochs":4,"lr":0.0001,"model_dir":"s3://sagemaker-us-east-1-209419068016/mobilenet/"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1588776170","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-209419068016/cnn-training-job-1588776170/source/sourcedir.tar.gz","module_name":"mobile-keras-addl-layer","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mobile-keras-addl-layer.py"}
# SM_USER_ARGS=["--batch_size","512","--epochs","4","--lr","0.0001","--model_dir","s3://sagemaker-us-east-1-209419068016/mobilenet/"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=512
# SM_HP_LR=0.0001
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-209419068016/mobilenet/
# SM_HP_EPOCHS=4
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mobile-keras-addl-layer.py --batch_size 512 --epochs 4 --lr 0.0001 --model_dir s3://sagemaker-us-east-1-209419068016/mobilenet/
#
#
# /usr/local/lib/python3.6/dist-packages/keras_applications/mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# #015   8192/9406464 [..............................] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0153309568/9406464 [=========>....................] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0159412608/9406464 [==============================] - 0s 0us/step
# Traceback (most recent call last):
#   File "mobile-keras-addl-layer.py", line 74, in <module>
#     base_learning_rate=args.lr)
#   File "mobile-keras-addl-layer.py", line 21, in model
#     addl_dense,
# NameError: name 'addl_dense' is not defined
# 2020-05-06 14:47:54,943 sagemaker-containers ERROR    ExecuteUserScriptError:
# Command "/usr/bin/python3 mobile-keras-addl-layer.py --batch_size 512 --epochs 4 --lr 0.0001 --model_dir s3://sagemaker-us-east-1-209419068016/mobilenet/"
#
# 2020-05-06 14:48:04 Uploading - Uploading generated training model
# 2020-05-06 14:48:04 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-11-fa13d948f26c> in <module>()
#      37             "ExperimentName": mobile_experiment.experiment_name,
#      38             "TrialName": cnn_trial.trial_name,
# ---> 39             "TrialComponentDisplayName": "Training",
#      40         }
#      41     )
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config, run_tensorboard_locally)
#     477                 tensorboard.join()
#     478         else:
# --> 479             fit_super()
#     480
#     481     @classmethod
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit_super()
#     456
#     457         def fit_super():
# --> 458             super(TensorFlow, self).fit(inputs, wait, logs, job_name, experiment_config)
#     459
#     460         if run_tensorboard_locally and wait is False:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     475         self.jobs.append(self.latest_training_job)
#     476         if wait:
# --> 477             self.latest_training_job.wait(logs=logs)
#     478
#     479     def _compilation_job_name(self):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1084         # If logs are requested, call logs_for_jobs.
#    1085         if logs != "None":
# -> 1086             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1087         else:
#    1088             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3042
#    3043         if wait:
# -> 3044             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3045             if dot:
#    3046                 print()
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    2636                 ),
#    2637                 allowed_statuses=["Completed", "Stopped"],
# -> 2638                 actual_status=status,
#    2639             )
#    2640
#
# UnexpectedStatusException: Error for Training job cnn-training-job-1588776170: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/usr/bin/python3 mobile-keras-addl-layer.py --batch_size 512 --epochs 4 --lr 0.0001 --model_dir s3://sagemaker-us-east-1-209419068016/mobilenet/"

# %%
mobile_estimator = TensorFlow(
                      entry_point=f'{script}.py', # this points to the script that will execute training
                      model_dir=output_uri, # where the model will eventually be saved
                     role=role,
                     train_instance_count=1, 
                     train_instance_type='ml.p3.8xlarge',
                     framework_version='2.1',
                     py_version='py3',
                    hyperparameters=hyperparameters,
                      script_mode=True,
                     distributions={'parameter_server': {'enabled': True}},
                    metric_definitions=[
                        {'Name':'train:loss', 'Regex':'Train Loss: (.*?);'},
                        {'Name':'test:loss', 'Regex':'Test Average loss: (.*?),'},
                        {'Name':'test:accuracy', 'Regex':'Test Accuracy: (.*?)%;'}
                    ],
)
mobile_estimator.hyperparameters()
# Out:
# WARNING:sagemaker:You have selected a multi-GPU training instance type. You have also enabled parameter server for distributed training. Distributed training with the default parameter server configuration will not fully leverage all GPU cores; the parameter server will be configured to run only one worker per host regardless of the number of GPUs.
# {'epochs': '4',
#  'sagemaker_submit_directory': '"s3://sagemaker-us-east-1-209419068016/cnn-training-job-1588774991/source/sourcedir.tar.gz"',
#  'sagemaker_program': '"mobile-keras.py"',
#  'sagemaker_enable_cloudwatch_metrics': 'false',
#  'sagemaker_container_log_level': '20',
#  'sagemaker_job_name': '"cnn-training-job-1588774991"',
#  'sagemaker_region': '"us-east-1"',
#  'sagemaker_parameter_server_enabled': 'true',
#  'model_dir': '"s3://sagemaker-us-east-1-209419068016/mobilenet/"'}

# %%
from sagemaker.analytics import ExperimentAnalytics
trial_component_analytics = ExperimentAnalytics(
    sagemaker_session=sess, 
    experiment_name=mobile_experiment.experiment_name
)
analytic_table = trial_component_analytics.dataframe()

# %%
analytic_table
# Out:
#                              TrialComponentName    DisplayName  \
# 0  cnn-training-job-1588771189-aws-training-job       Training
# 1  cnn-training-job-1588770694-aws-training-job       Training
# 2         TrialComponent-2020-05-06-131131-qxrw  Preprocessing
#
#                                            SourceArn  \
# 0  arn:aws:sagemaker:us-east-1:209419068016:train...
# 1  arn:aws:sagemaker:us-east-1:209419068016:train...
# 2                                                NaN
#
#                                   SageMaker.ImageUri  SageMaker.InstanceCount  \
# 0  763104351884.dkr.ecr.us-east-1.amazonaws.com/t...                      1.0
# 1  763104351884.dkr.ecr.us-east-1.amazonaws.com/t...                      1.0
# 2                                                NaN                      NaN
#
#   SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0          ml.p3.8xlarge                      30.0
# 1          ml.p3.8xlarge                      30.0
# 2                    NaN                       NaN
#
#                                            model_dir  \
# 0  "s3://sagemaker-us-east-1-209419068016/mobilen...
# 1  "s3://sagemaker-us-east-1-209419068016/mobilen...
# 2                                                NaN
#
#    sagemaker_container_log_level sagemaker_enable_cloudwatch_metrics  \
# 0                           20.0                               false
# 1                           20.0                               false
# 2                            NaN                                 NaN
#
#               sagemaker_job_name sagemaker_parameter_server_enabled  \
# 0  "cnn-training-job-1588771189"                               true
# 1  "cnn-training-job-1588770694"                               true
# 2                            NaN                                NaN
#
#               sagemaker_program sagemaker_region  \
# 0  "mobile-keras-addl-layer.py"      "us-east-1"
# 1             "mobile-keras.py"      "us-east-1"
# 2                           NaN              NaN
#
#                           sagemaker_submit_directory
# 0  "s3://sagemaker-us-east-1-209419068016/cnn-tra...
# 1  "s3://sagemaker-us-east-1-209419068016/cnn-tra...
# 2                                                NaN

# %%
trial_component_analytics = ExperimentAnalytics(
    sagemaker_session=sess, 
    experiment_name=mobile_experiment.experiment_name,
    sort_by="metrics.test:accuracy.max",
    sort_order="Descending",
    metric_names=['test:accuracy'],
    parameter_names=['hidden_channels', 'epochs', 'dropout', 'optimizer']
)
analytic_table = trial_component_analytics.dataframe()

# %%
mobile_estimator.deploy(initial_instance_count=1, instance_type='ml.m5.2xlarge', endpoint_name='mobile-endpoint')
# Out:
# Using already existing model: tensorflow-training-2020-05-05-18-32-58-238
# -----
