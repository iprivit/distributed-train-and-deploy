# %% [markdown]
# # NEO and Elastic Inference
# 1. [Introduction](#Introduction)
# 2. [Prerequisites and Preprocessing](#Prequisites-and-Preprocessing)
# 3. [Training the model](#Training-the-model)
# 4. [Inference with the vanilla model](#Inference-with-the-vanilla-model)
# 5. [Inference with optimized model](#Inference-with-the-optimized-model)

# %% [markdown]
# ## Introduction
#
# Welcome to our model optimization example for image classification.
#
# In this demo, we will use the Amazon sagemaker image classification algorithm to train on the [caltech-256 dataset](http://www.vision.caltech.edu/Image_Datasets/Caltech256/) and then we will demonstrate Amazon Sagemaker Neo's ability to optimize models.
#
#
# To get started, we need to set up the environment with a few prerequisite steps, for permissions, configurations, and so on.

# %% [markdown]
# ## Prequisites and Preprocessing
#
# ### Permissions and environment variables
#
# Here we set up the linkage and authentication to AWS services. There are three parts to this:
#
# * The roles used to give learning and hosting access to your data. This will automatically be obtained from the role used to start the notebook
# * The S3 bucket that you want to use for training and model data
# * The Amazon sagemaker image classification docker image which need not be changed

# %%
from __future__ import print_function

import sagemaker
from sagemaker import get_execution_role
import mxnet as mx

import mxnet.ndarray as nd
from mxnet import nd, autograd, gluon
from mxnet.gluon.data.vision import transforms

import numpy as np
from tqdm import tqdm

role = get_execution_role()
sess = sagemaker.Session()
bucket=sess.default_bucket()
prefix = 'ic-neo'

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

training_image = get_image_uri(sess.boto_region_name, 'image-classification', repo_version="latest")

# %% [markdown]
# ### Data preparation
# Download the data and transfer to S3 for use in training. In this demo, we are using [Caltech-256](http://www.vision.caltech.edu/Image_Datasets/Caltech256/) dataset, which contains 30608 images of 256 objects. For the training and validation data, we follow the splitting scheme in this MXNet [example](https://github.com/apache/incubator-mxnet/blob/master/example/image-classification/data/caltech256.sh). In particular, it randomly selects 60 images per class for training, and uses the remaining data for validation. The algorithm takes `RecordIO` file as input. The user can also provide the image files as input, which will be converted into `RecordIO` format using MXNet's [im2rec](https://mxnet.incubator.apache.org/how_to/recordio.html?highlight=im2rec) tool. It takes around 50 seconds to convert the entire Caltech-256 dataset (~1.2GB) on a p2.xlarge instance. However, for this demo, we will use record io format.

# %%
import os 
import urllib.request
import boto3

def download(url):
    filename = url.split("/")[-1]
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url, filename)

        
def upload_to_s3(channel, file):
    s3 = boto3.resource('s3')
    data = open(file, "rb")
    key = channel + '/' + file
    s3.Bucket(bucket).put_object(Key=key, Body=data)


# caltech-256
#download('http://data.mxnet.io/data/caltech-256/caltech-256-60-train.rec')
#download('http://data.mxnet.io/data/caltech-256/caltech-256-60-val.rec')

# %%
#tree = os.walk('/home/ec2-user/SageMaker')
#tree.
# paths = []
# dirss = []
# filess = []
# for path, dirs, files in os.walk('/home/ec2-user/SageMaker/256_ObjectCategories/', followlinks=True):
#     paths.append(path)
#     dirss.append(dirs)
#     filess.append(files)

# %%
from glob import glob

dirs = os.listdir('/home/ec2-user/SageMaker/256_ObjectCategories/')
dir_dict = {}
for d in dirs:
    files = glob(f'/home/ec2-user/SageMaker/256_ObjectCategories/{d}/*jpg')
    files.sort()
    dir_dict[d] = files

# %%
#!cd .. && mkdir train1_256
#!cd .. && mkdir train2_256

# %%
for d in tqdm(dir_dict):
    for path in dir_dict[d][:30]:
        try:
            os.mkdir(f'/home/ec2-user/SageMaker/train_256_01/{d}')
        except:
            print(f'path: /home/ec2-user/SageMaker/train_256_01/{d} already exists!')
        os.system(f'cp {path} /home/ec2-user/SageMaker/train_256_01/{d}')
    
    for path in dir_dict[d][30:60]:
        try:
            os.mkdir(f'/home/ec2-user/SageMaker/train_256_02/{d}')
        except:
            print(f'path: /home/ec2-user/SageMaker/train_256_02/{d} already exists!')
        os.system(f'cp {path} /home/ec2-user/SageMaker/train_256_02/{d}')
# Out:
#   0%|          | 0/257 [00:00<?, ?it/s]
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
#   5%|▌         | 14/257 [00:00<00:05, 41.13it/s]
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_02/126.ladder already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
#  28%|██▊       | 72/257 [00:00<00:03, 53.99it/s]
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_02/008.bathtub already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/132.light-house already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
#  31%|███       | 79/257 [00:01<00:05, 33.59it/s]
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/251.airplanes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
#  37%|███▋      | 95/257 [00:01<00:04, 36.87it/s]
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_02/257.clutter already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
#  39%|███▉      | 101/257 [00:01<00:05, 27.90it/s]
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/145.motorbikes-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
#  53%|█████▎    | 137/257 [00:02<00:03, 35.87it/s]
# path: /home/ec2-user/SageMaker/train_256_01/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_02/105.horse already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
#  60%|█████▉    | 154/257 [00:02<00:02, 39.25it/s]
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_02/232.t-shirt already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
#  62%|██████▏   | 160/257 [00:02<00:02, 38.43it/s]
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/159.people already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
#  65%|██████▍   | 166/257 [00:02<00:02, 35.32it/s]
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_02/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_02/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_02/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_02/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_02/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_02/012.binoculars already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/147.mushroom already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
#  67%|██████▋   | 171/257 [00:03<00:04, 21.11it/s]
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_02/011.billiards already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/092.grapes already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
#  68%|██████▊   | 175/257 [00:03<00:05, 14.88it/s]
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_02/096.hammock already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
#  75%|███████▌  | 193/257 [00:03<00:03, 20.40it/s]
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/240.watch-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/129.leopards-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
#  87%|████████▋ | 223/257 [00:04<00:01, 27.27it/s]
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_02/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_02/090.gorilla already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_01/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# path: /home/ec2-user/SageMaker/train_256_02/253.faces-easy-101 already exists!
# 100%|██████████| 257/257 [00:04<00:00, 58.34it/s]
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!
# path: /home/ec2-user/SageMaker/train_256_01/138.mattress already exists!

# %%
# need to split into multiple train files

# %%
#!python im2rec.py --help

# %%
#!pwd

# %%
# %%sh
#
# # wget http://www.vision.caltech.edu/Image_Datasets/Caltech256/256_ObjectCategories.tar
# # tar -xf 256_ObjectCategories.tar
# # cd ..
#
# # mkdir -p caltech_256_train_60
# # for i in 256_ObjectCategories/*; do
# #     c=`basename $i`
# #     mkdir -p caltech_256_train_60/$c
# #     for j in `ls $i/*.jpg | shuf | head -n 60`; do
# #         mv $j caltech_256_train_60/$c/
# #     done
# # done
#
# python distributed-train-and-deploy/im2rec.py --list --recursive caltech-256-60-train caltech_256_train_60/
# python distributed-train-and-deploy/im2rec.py --list --recursive caltech-256-60-val 256_ObjectCategories/
# python distributed-train-and-deploy/im2rec.py --resize 256 --quality 90 --num-thread 16 caltech-256-60-val 256_ObjectCategories/
# python distributed-train-and-deploy/im2rec.py --resize 256 --quality 90 --num-thread 16 caltech-256-60-train caltech_256_train_60/
# Out:
# 001.ak47 0
# 002.american-flag 1
# 003.backpack 2
# 004.baseball-bat 3
# 005.baseball-glove 4
# 006.basketball-hoop 5
# 007.bat 6
# 008.bathtub 7
# 009.bear 8
# 010.beer-mug 9
# 011.billiards 10
# 012.binoculars 11
# 013.birdbath 12
# 014.blimp 13
# 015.bonsai-101 14
# 016.boom-box 15
# 017.bowling-ball 16
# 018.bowling-pin 17
# 019.boxing-glove 18
# 020.brain-101 19
# 021.breadmaker 20
# 022.buddha-101 21
# 023.bulldozer 22
# 024.butterfly 23
# 025.cactus 24
# 026.cake 25
# 027.calculator 26
# 028.camel 27
# 029.cannon 28
# 030.canoe 29
# 031.car-tire 30
# 032.cartman 31
# 033.cd 32
# 034.centipede 33
# 035.cereal-box 34
# 036.chandelier-101 35
# 037.chess-board 36
# 038.chimp 37
# 039.chopsticks 38
# 040.cockroach 39
# 041.coffee-mug 40
# 042.coffin 41
# 043.coin 42
# 044.comet 43
# 045.computer-keyboard 44
# 046.computer-monitor 45
# 047.computer-mouse 46
# 048.conch 47
# 049.cormorant 48
# 050.covered-wagon 49
# 051.cowboy-hat 50
# 052.crab-101 51
# 053.desk-globe 52
# 054.diamond-ring 53
# 055.dice 54
# 056.dog 55
# 057.dolphin-101 56
# 058.doorknob 57
# 059.drinking-straw 58
# 060.duck 59
# 061.dumb-bell 60
# 062.eiffel-tower 61
# 063.electric-guitar-101 62
# 064.elephant-101 63
# 065.elk 64
# 066.ewer-101 65
# 067.eyeglasses 66
# 068.fern 67
# 069.fighter-jet 68
# 070.fire-extinguisher 69
# 071.fire-hydrant 70
# 072.fire-truck 71
# 073.fireworks 72
# 074.flashlight 73
# 075.floppy-disk 74
# 076.football-helmet 75
# 077.french-horn 76
# 078.fried-egg 77
# 079.frisbee 78
# 080.frog 79
# 081.frying-pan 80
# 082.galaxy 81
# 083.gas-pump 82
# 084.giraffe 83
# 085.goat 84
# 086.golden-gate-bridge 85
# 087.goldfish 86
# 088.golf-ball 87
# 089.goose 88
# 090.gorilla 89
# 091.grand-piano-101 90
# 092.grapes 91
# 093.grasshopper 92
# 094.guitar-pick 93
# 095.hamburger 94
# 096.hammock 95
# 097.harmonica 96
# 098.harp 97
# 099.harpsichord 98
# 100.hawksbill-101 99
# 101.head-phones 100
# 102.helicopter-101 101
# 103.hibiscus 102
# 104.homer-simpson 103
# 105.horse 104
# 106.horseshoe-crab 105
# 107.hot-air-balloon 106
# 108.hot-dog 107
# 109.hot-tub 108
# 110.hourglass 109
# 111.house-fly 110
# 112.human-skeleton 111
# 113.hummingbird 112
# 114.ibis-101 113
# 115.ice-cream-cone 114
# 116.iguana 115
# 117.ipod 116
# 118.iris 117
# 119.jesus-christ 118
# 120.joy-stick 119
# 121.kangaroo-101 120
# 122.kayak 121
# 123.ketch-101 122
# 124.killer-whale 123
# 125.knife 124
# 126.ladder 125
# 127.laptop-101 126
# 128.lathe 127
# 129.leopards-101 128
# 130.license-plate 129
# 131.lightbulb 130
# 132.light-house 131
# 133.lightning 132
# 134.llama-101 133
# 135.mailbox 134
# 136.mandolin 135
# 137.mars 136
# 138.mattress 137
# 139.megaphone 138
# 140.menorah-101 139
# 141.microscope 140
# 142.microwave 141
# 143.minaret 142
# 144.minotaur 143
# 145.motorbikes-101 144
# 146.mountain-bike 145
# 147.mushroom 146
# 148.mussels 147
# 149.necktie 148
# 150.octopus 149
# 151.ostrich 150
# 152.owl 151
# 153.palm-pilot 152
# 154.palm-tree 153
# 155.paperclip 154
# 156.paper-shredder 155
# 157.pci-card 156
# 158.penguin 157
# 159.people 158
# 160.pez-dispenser 159
# 161.photocopier 160
# 162.picnic-table 161
# 163.playing-card 162
# 164.porcupine 163
# 165.pram 164
# 166.praying-mantis 165
# 167.pyramid 166
# 168.raccoon 167
# 169.radio-telescope 168
# 170.rainbow 169
# 171.refrigerator 170
# 172.revolver-101 171
# 173.rifle 172
# 174.rotary-phone 173
# 175.roulette-wheel 174
# 176.saddle 175
# 177.saturn 176
# 178.school-bus 177
# 179.scorpion-101 178
# 180.screwdriver 179
# 181.segway 180
# 182.self-propelled-lawn-mower 181
# 183.sextant 182
# 184.sheet-music 183
# 185.skateboard 184
# 186.skunk 185
# 187.skyscraper 186
# 188.smokestack 187
# 189.snail 188
# 190.snake 189
# 191.sneaker 190
# 192.snowmobile 191
# 193.soccer-ball 192
# 194.socks 193
# 195.soda-can 194
# 196.spaghetti 195
# 197.speed-boat 196
# 198.spider 197
# 199.spoon 198
# 200.stained-glass 199
# 201.starfish-101 200
# 202.steering-wheel 201
# 203.stirrups 202
# 204.sunflower-101 203
# 205.superman 204
# 206.sushi 205
# 207.swan 206
# 208.swiss-army-knife 207
# 209.sword 208
# 210.syringe 209
# 211.tambourine 210
# 212.teapot 211
# 213.teddy-bear 212
# 214.teepee 213
# 215.telephone-box 214
# 216.tennis-ball 215
# 217.tennis-court 216
# 218.tennis-racket 217
# 219.theodolite 218
# 220.toaster 219
# 221.tomato 220
# 222.tombstone 221
# 223.top-hat 222
# 224.touring-bike 223
# 225.tower-pisa 224
# 226.traffic-light 225
# 227.treadmill 226
# 228.triceratops 227
# 229.tricycle 228
# 230.trilobite-101 229
# 231.tripod 230
# 232.t-shirt 231
# 233.tuning-fork 232
# 234.tweezer 233
# 235.umbrella-101 234
# 236.unicorn 235
# 237.vcr 236
# 238.video-projector 237
# 239.washing-machine 238
# 240.watch-101 239
# 241.waterfall 240
# 242.watermelon 241
# 243.welding-mask 242
# 244.wheelbarrow 243
# 245.windmill 244
# 246.wine-bottle 245
# 247.xylophone 246
# 248.yarmulke 247
# 249.yo-yo 248
# 250.zebra 249
# 251.airplanes-101 250
# 252.car-side-101 251
# 253.faces-easy-101 252
# 254.greyhound 253
# 255.tennis-shoes 254
# 256.toad 255
# 257.clutter 256
# 002.american-flag/.ipynb_checkpoints 0
# 008.bathtub 1
# 011.billiards 2
# 012.binoculars 3
# 076.football-helmet/.ipynb_checkpoints 4
# 090.gorilla 5
# 092.grapes 6
# 096.hammock 7
# 105.horse 8
# 126.ladder 9
# 129.leopards-101 10
# 132.light-house 11
# 138.mattress 12
# 145.motorbikes-101 13
# 147.mushroom 14
# 159.people 15
# 232.t-shirt 16
# 240.watch-101 17
# 251.airplanes-101 18
# 253.faces-easy-101 19
# 257.clutter 20
# ls: cannot access 256_ObjectCategories/001.ak47/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/002.american-flag/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/006.basketball-hoop/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/007.bat/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/009.bear/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/010.beer-mug/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/013.birdbath/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/014.blimp/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/016.boom-box/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/017.bowling-ball/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/018.bowling-pin/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/020.brain-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/022.buddha-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/023.bulldozer/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/024.butterfly/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/025.cactus/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/026.cake/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/027.calculator/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/028.camel/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/029.cannon/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/030.canoe/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/031.car-tire/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/032.cartman/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/033.cd/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/034.centipede/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/035.cereal-box/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/036.chandelier-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/037.chess-board/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/038.chimp/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/039.chopsticks/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/041.coffee-mug/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/042.coffin/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/045.computer-keyboard/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/047.computer-mouse/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/048.conch/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/049.cormorant/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/050.covered-wagon/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/051.cowboy-hat/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/052.crab-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/053.desk-globe/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/054.diamond-ring/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/055.dice/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/056.dog/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/057.dolphin-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/058.doorknob/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/059.drinking-straw/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/060.duck/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/061.dumb-bell/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/062.eiffel-tower/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/065.elk/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/066.ewer-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/067.eyeglasses/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/068.fern/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/069.fighter-jet/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/070.fire-extinguisher/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/071.fire-hydrant/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/072.fire-truck/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/073.fireworks/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/074.flashlight/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/075.floppy-disk/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/076.football-helmet/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/077.french-horn/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/078.fried-egg/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/079.frisbee/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/080.frog/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/081.frying-pan/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/082.galaxy/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/083.gas-pump/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/084.giraffe/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/085.goat/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/086.golden-gate-bridge/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/087.goldfish/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/088.golf-ball/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/089.goose/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/091.grand-piano-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/093.grasshopper/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/094.guitar-pick/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/095.hamburger/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/097.harmonica/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/098.harp/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/099.harpsichord/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/100.hawksbill-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/102.helicopter-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/103.hibiscus/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/104.homer-simpson/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/106.horseshoe-crab/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/107.hot-air-balloon/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/108.hot-dog/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/110.hourglass/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/111.house-fly/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/112.human-skeleton/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/113.hummingbird/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/114.ibis-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/115.ice-cream-cone/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/116.iguana/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/118.iris/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/119.jesus-christ/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/121.kangaroo-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/122.kayak/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/123.ketch-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/124.killer-whale/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/125.knife/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/128.lathe/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/130.license-plate/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/131.lightbulb/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/134.llama-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/135.mailbox/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/136.mandolin/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/139.megaphone/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/140.menorah-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/141.microscope/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/142.microwave/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/144.minotaur/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/146.mountain-bike/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/149.necktie/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/150.octopus/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/151.ostrich/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/152.owl/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/153.palm-pilot/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/154.palm-tree/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/155.paperclip/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/156.paper-shredder/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/157.pci-card/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/160.pez-dispenser/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/161.photocopier/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/162.picnic-table/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/163.playing-card/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/164.porcupine/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/165.pram/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/166.praying-mantis/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/167.pyramid/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/169.radio-telescope/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/170.rainbow/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/171.refrigerator/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/172.revolver-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/173.rifle/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/174.rotary-phone/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/175.roulette-wheel/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/176.saddle/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/177.saturn/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/178.school-bus/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/179.scorpion-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/180.screwdriver/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/181.segway/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/182.self-propelled-lawn-mower/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/183.sextant/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/184.sheet-music/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/185.skateboard/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/186.skunk/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/187.skyscraper/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/188.smokestack/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/189.snail/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/190.snake/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/191.sneaker/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/192.snowmobile/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/194.socks/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/195.soda-can/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/196.spaghetti/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/197.speed-boat/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/198.spider/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/199.spoon/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/200.stained-glass/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/201.starfish-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/202.steering-wheel/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/203.stirrups/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/204.sunflower-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/205.superman/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/206.sushi/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/207.swan/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/208.swiss-army-knife/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/209.sword/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/210.syringe/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/211.tambourine/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/213.teddy-bear/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/215.telephone-box/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/216.tennis-ball/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/217.tennis-court/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/218.tennis-racket/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/219.theodolite/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/220.toaster/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/221.tomato/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/222.tombstone/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/223.top-hat/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/224.touring-bike/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/225.tower-pisa/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/226.traffic-light/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/228.triceratops/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/229.tricycle/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/230.trilobite-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/231.tripod/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/233.tuning-fork/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/235.umbrella-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/236.unicorn/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/237.vcr/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/238.video-projector/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/239.washing-machine/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/241.waterfall/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/242.watermelon/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/243.welding-mask/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/244.wheelbarrow/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/245.windmill/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/246.wine-bottle/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/247.xylophone/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/248.yarmulke/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/249.yo-yo/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/250.zebra/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/252.car-side-101/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/254.greyhound/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/255.tennis-shoes/*.jpg: No such file or directory
# ls: cannot access 256_ObjectCategories/256.toad/*.jpg: No such file or directory

# %%
# !cd .. && mkdir caltech-256-train1
# !cd .. && mkdir caltech-256-train2

# %%
# /home/ec2-user/SageMaker/
# /home/ec2-user/SageMaker/
#!cd .. && python distributed-train-and-deploy/im2rec.py --list True --recursive True caltech-256-train1 train1_256/

# %%
# !cd .. && python distributed-train-and-deploy/im2rec.py --list --recursive caltech-256-train1 train1_256/
# !cd .. && python distributed-train-and-deploy/im2rec.py --list --recursive caltech-256-train2 train2_256/
# !cd .. && python distributed-train-and-deploy/im2rec.py --resize 256 --quality 90 --num-thread 16 caltech-256-train1 train1_256/
# !cd .. && python distributed-train-and-deploy/im2rec.py --resize 256 --quality 90 --num-thread 16 caltech-256-train2 train2_256/
# Out:
# usage: im2rec.py [-h] [--list] [--exts EXTS [EXTS ...]] [--chunks CHUNKS]
#                  [--train-ratio TRAIN_RATIO] [--test-ratio TEST_RATIO]
#                  [--recursive] [--no-shuffle] [--pass-through]
#                  [--resize RESIZE] [--center-crop] [--quality QUALITY]
#                  [--num-thread NUM_THREAD] [--color {-1,0,1}]
#                  [--encoding {.jpg,.png}] [--pack-label]
#                  prefix root
# im2rec.py: error: unrecognized arguments: caltech-256-train1 train1_256/
# usage: im2rec.py [-h] [--list] [--exts EXTS [EXTS ...]] [--chunks CHUNKS]
#                  [--train-ratio TRAIN_RATIO] [--test-ratio TEST_RATIO]
#                  [--recursive] [--no-shuffle] [--pass-through]
#                  [--resize RESIZE] [--center-crop] [--quality QUALITY]
#                  [--num-thread NUM_THREAD] [--color {-1,0,1}]
#                  [--encoding {.jpg,.png}] [--pack-label]
#                  prefix root
# im2rec.py: error: unrecognized arguments: caltech-256-train2 train2_256/
# Did not find and list file with prefix /home/ec2-user/SageMaker/caltech-256-train1
# Did not find and list file with prefix /home/ec2-user/SageMaker/caltech-256-train2

# %%
record = mx.recordio.MXRecordIO('caltech-256-60-train.rec', 'r')
item = record.read()
header, img = mx.recordio.unpack_img(item)

# %%
# Four channels: train, validation, train_lst, and validation_lst
s3train = 's3://{}/{}/train/'.format(bucket, prefix)
s3validation = 's3://{}/{}/validation/'.format(bucket, prefix)

# upload the lst files to train and validation channels
# !aws s3 cp caltech-256-60-train.rec $s3train --quiet
# !aws s3 cp caltech-256-60-val.rec $s3validation --quiet

# %% [markdown]
# Once we have the data available in the correct format for training, the next step is to actually train the model using the data. After setting training parameters, we kick off training, and poll for status until training is completed.

# %% [markdown]
# ## Training the model
#
# Now that we are done with all the setup that is needed, we are ready to train our object detector. To begin, let us create a ``sageMaker.estimator.Estimator`` object. This estimator will launch the training job.
# ### Training parameters
# There are two kinds of parameters that need to be set for training. The first one are the parameters for the training job. These include:
#
# * **Training instance count**: This is the number of instances on which to run the training. When the number of instances is greater than one, then the image classification algorithm will run in distributed settings. ml.p3.8xlarge has 4 x Nvidia V100.  https://aws.amazon.com/sagemaker/pricing/instance-types/
# * **Training instance type**: This indicates the type of machine on which to run the training. Typically, we use GPU instances for these training
# * **Output path**: This the s3 folder in which the training output is stored

# %%
s3_output_location = 's3://{}/{}/output-ic'.format(bucket, prefix)
ic = sagemaker.estimator.Estimator(training_image,
                                         role, 
                                         train_instance_count=1, 
                                         train_instance_type='ml.p3.8xlarge', 
                                         train_volume_size = 50,
                                         train_max_run = 360000,
                                         input_mode= 'Pipe',
                                         output_path=s3_output_location,
                                         sagemaker_session=sess)

# %% [markdown]
# Apart from the above set of parameters, there are hyperparameters that are specific to the algorithm. These are:
#
# https://docs.aws.amazon.com/sagemaker/latest/dg/IC-Hyperparameter.html
#
# * **num_layers**: The number of layers (depth) for the network. Valid values: For data with large image size (224x224) positive integer in [18, 34, 50, 101, 152, 200] or for data with small image size (28x28) use [20, 32, 44, 56, 110]
# * **image_shape**: The input image dimensions,'num_channels, height, width', for the network. It should be no larger than the actual image size. The number of channels should be same as the actual image.
# * **num_classes**: This is the number of output classes for the new dataset. Imagenet was trained with 1000 output classes but the number of output classes can be changed for fine-tuning. For caltech, we use 257 because it has 256 object categories + 1 clutter class.
# * **num_training_samples**: This is the total number of training samples. It is set to 15240 for caltech dataset with the current split.
# * **mini_batch_size**: The number of training samples used for each mini batch. In distributed training, the number of training samples used per batch will be N * mini_batch_size where N is the number of hosts on which training is run.
# * **epochs**: Number of training epochs.
# * **learning_rate**: Learning rate for training.
# * **top_k**: Report the top-k accuracy during training.
# * **precision_dtype**: Training datatype precision (default: float32). If set to 'float16', the training will be done in mixed_precision mode and will be faster than float32 mode
# * **use_pretrained_model**:  Flag to use pre-trained model for training. If set to 1, then the pretrained model with the corresponding number of layers is loaded and used for training. Only the top FC layer are reinitialized with random weights. Otherwise, the network is trained from scratch.

# %%
ic.set_hyperparameters(num_layers=101,
                             image_shape = "3,224,224",
                             num_classes=257,
                             num_training_samples=15420,
                             mini_batch_size=128,
                             epochs=2,
                             learning_rate=0.0002,
                             top_k=2,
                             precision_dtype='float32',
                             use_pretrained_model=1)

# %% [markdown]
# ## Input data specification
# Set the data type and channels used for training

# %%
# change to shardbys3
train_data = sagemaker.session.s3_input(s3train, distribution='FullyReplicated', 
                        content_type='application/x-recordio', s3_data_type='S3Prefix')

validation_data = sagemaker.session.s3_input(s3validation, distribution='FullyReplicated', 
                             content_type='application/x-recordio', s3_data_type='S3Prefix')

data_channels = {'train': train_data, 'validation': validation_data}

# %% [markdown]
# ## Start the training
# Start training by calling the fit method in the estimator

# %%
ic.fit(inputs=data_channels, logs=True)

# %% [markdown]
# # Inference with the vanilla model
#
# ***
#
# Now we will test the trained model without any specific optimization for the hardware.

# %%
ic_vanilla = ic.deploy(initial_instance_count = 1,
                          instance_type = 'ml.p3.2xlarge')

# %% [markdown]
# ### Download test image

# %%
# !wget -O /tmp/test-1.jpg http://www.vision.caltech.edu/Image_Datasets/Caltech256/images/080.frog/080_0001.jpg
# !wget -O /tmp/test-2.jpg http://www.vision.caltech.edu/Image_Datasets/Caltech256/images/002.american-flag/002_0004.jpg
# !wget -O /tmp/test-3.jpg http://www.vision.caltech.edu/Image_Datasets/Caltech256/images/037.chess-board/037_0006.jpg
# !wget -O /tmp/test-4.jpg http://www.vision.caltech.edu/Image_Datasets/Caltech256/images/086.golden-gate-bridge/086_0010.jpg

# %% [markdown]
# ### Evaluation
#
# Evaluate the image through the network for inteference. The network outputs class probabilities and typically, one selects the class with the maximum probability as the final class output.
#
# **Note:** The output class detected by the network may not be accurate in this example. To limit the time taken and cost of training, we have trained the model only for 5 epochs. If the network is trained for more epochs (say 20), then the output class will be more accurate.

# %%
#file_name = '/tmp/test-1.jpg'
file_name = '/tmp/test-2.jpg'
#file_name = '/tmp/test-3.jpg'
#file_name = '/tmp/test-4.jpg'
# test image
from IPython.display import Image
Image(file_name)

# %%
import json
import numpy as np

with open(file_name, 'rb') as f:
    payload = f.read()
    payload = bytearray(payload)
    
ic_vanilla.content_type = 'application/x-image'

# %% [markdown]
# **Time the prediction with the vanilla model.**

# %%
result = json.loads(ic_vanilla.predict(payload))

# %%
# the result will output the probabilities for all classes
# find the class with maximum probability and print the class index
index = np.argmax(result)
object_categories = ['ak47', 'american-flag', 'backpack', 'baseball-bat', 'baseball-glove', 'basketball-hoop', 'bat', 'bathtub', 'bear', 'beer-mug', 'billiards', 'binoculars', 'birdbath', 'blimp', 'bonsai-101', 'boom-box', 'bowling-ball', 'bowling-pin', 'boxing-glove', 'brain-101', 'breadmaker', 'buddha-101', 'bulldozer', 'butterfly', 'cactus', 'cake', 'calculator', 'camel', 'cannon', 'canoe', 'car-tire', 'cartman', 'cd', 'centipede', 'cereal-box', 'chandelier-101', 'chess-board', 'chimp', 'chopsticks', 'cockroach', 'coffee-mug', 'coffin', 'coin', 'comet', 'computer-keyboard', 'computer-monitor', 'computer-mouse', 'conch', 'cormorant', 'covered-wagon', 'cowboy-hat', 'crab-101', 'desk-globe', 'diamond-ring', 'dice', 'dog', 'dolphin-101', 'doorknob', 'drinking-straw', 'duck', 'dumb-bell', 'eiffel-tower', 'electric-guitar-101', 'elephant-101', 'elk', 'ewer-101', 'eyeglasses', 'fern', 'fighter-jet', 'fire-extinguisher', 'fire-hydrant', 'fire-truck', 'fireworks', 'flashlight', 'floppy-disk', 'football-helmet', 'french-horn', 'fried-egg', 'frisbee', 'frog', 'frying-pan', 'galaxy', 'gas-pump', 'giraffe', 'goat', 'golden-gate-bridge', 'goldfish', 'golf-ball', 'goose', 'gorilla', 'grand-piano-101', 'grapes', 'grasshopper', 'guitar-pick', 'hamburger', 'hammock', 'harmonica', 'harp', 'harpsichord', 'hawksbill-101', 'head-phones', 'helicopter-101', 'hibiscus', 'homer-simpson', 'horse', 'horseshoe-crab', 'hot-air-balloon', 'hot-dog', 'hot-tub', 'hourglass', 'house-fly', 'human-skeleton', 'hummingbird', 'ibis-101', 'ice-cream-cone', 'iguana', 'ipod', 'iris', 'jesus-christ', 'joy-stick', 'kangaroo-101', 'kayak', 'ketch-101', 'killer-whale', 'knife', 'ladder', 'laptop-101', 'lathe', 'leopards-101', 'license-plate', 'lightbulb', 'light-house', 'lightning', 'llama-101', 'mailbox', 'mandolin', 'mars', 'mattress', 'megaphone', 'menorah-101', 'microscope', 'microwave', 'minaret', 'minotaur', 'motorbikes-101', 'mountain-bike', 'mushroom', 'mussels', 'necktie', 'octopus', 'ostrich', 'owl', 'palm-pilot', 'palm-tree', 'paperclip', 'paper-shredder', 'pci-card', 'penguin', 'people', 'pez-dispenser', 'photocopier', 'picnic-table', 'playing-card', 'porcupine', 'pram', 'praying-mantis', 'pyramid', 'raccoon', 'radio-telescope', 'rainbow', 'refrigerator', 'revolver-101', 'rifle', 'rotary-phone', 'roulette-wheel', 'saddle', 'saturn', 'school-bus', 'scorpion-101', 'screwdriver', 'segway', 'self-propelled-lawn-mower', 'sextant', 'sheet-music', 'skateboard', 'skunk', 'skyscraper', 'smokestack', 'snail', 'snake', 'sneaker', 'snowmobile', 'soccer-ball', 'socks', 'soda-can', 'spaghetti', 'speed-boat', 'spider', 'spoon', 'stained-glass', 'starfish-101', 'steering-wheel', 'stirrups', 'sunflower-101', 'superman', 'sushi', 'swan', 'swiss-army-knife', 'sword', 'syringe', 'tambourine', 'teapot', 'teddy-bear', 'teepee', 'telephone-box', 'tennis-ball', 'tennis-court', 'tennis-racket', 'theodolite', 'toaster', 'tomato', 'tombstone', 'top-hat', 'touring-bike', 'tower-pisa', 'traffic-light', 'treadmill', 'triceratops', 'tricycle', 'trilobite-101', 'tripod', 't-shirt', 'tuning-fork', 'tweezer', 'umbrella-101', 'unicorn', 'vcr', 'video-projector', 'washing-machine', 'watch-101', 'waterfall', 'watermelon', 'welding-mask', 'wheelbarrow', 'windmill', 'wine-bottle', 'xylophone', 'yarmulke', 'yo-yo', 'zebra', 'airplanes-101', 'car-side-101', 'faces-easy-101', 'greyhound', 'tennis-shoes', 'toad', 'clutter']
print("Result: label - " + object_categories[index] + ", probability - " + str(result[index]))

# %% [markdown]
# ## Inference with the Elastic Compute

# %%
from sagemaker import Model

# %%
ic_model = Model(model_data="s3://sagemaker-us-east-2-425479682919/ic/output/image-classification-2020-05-06-16-50-22-338/output/model.tar.gz",
                    role=role,
                    image=training_image)

# %%
ic_eia = ic_model.deploy(initial_instance_count = 1,
                          instance_type = 'ml.c5.large',
                          accelerator_type='ml.eia2.medium')

# %%
result = json.loads(ic_eia.predict(payload))

# %% [markdown]
# # Inference with the optimized model
#
# ***
#
# We will use Sagemaker Neo to optimize the model.

# %% [markdown]
# ## Introduction to SageMaker Neo
#
# ***
#
# [Amazon SageMaker Neo](https://aws.amazon.com/sagemaker/neo/) optimizes models to run up to fourth as fast, with less than a tenth of the memory footprint, with no loss in accuracy. You start with a machine learning model built using MXNet, TensorFlow, PyTorch, or XGBoost and trained using Amazon SageMaker. Then you choose your target hardware platform from Intel, NVIDIA, or ARM. With a single click, SageMaker Neo will then compile the trained model into an executable. In this example, we will use the model we just trained and see how well the optimized model could perform.

# %% [markdown]
# ## Optimize the model specifically for the architecture using Neo API
# Now we will compare the same model, but compiled specifically for the architecture we're deploying on.

# %%
output_path = '/'.join(ic.output_path.split('/')[:-1])

optimized_ic = ic.compile_model(target_instance_family='ml_p3', 
                                input_shape={'data':[1, 3, 224, 224]},  # Batch size 1, 3 channels, 224x224 Images.
                                output_path=output_path,
                                framework='mxnet', framework_version='gpu')

# %%
optimized_ic.image = get_image_uri(sess.boto_region_name, 'image-classification-neo', repo_version="gpu")

optimized_ic.name = 'deployed-image-classification-neo'

# %% [markdown]
# ## Deploy optimized model

# %%
optimized_ic_classifier = optimized_ic.deploy(initial_instance_count = 1,
                                              instance_type = 'ml.p3.2xlarge')

# %% [markdown]
# ## Make predictions

# %%
optimized_ic_classifier.content_type = 'application/x-image'

# %% [markdown]
# **Time the prediction with the optimized model.** We compare the optimized predictions times to the vanilla predictions times.

# %%
result = json.loads(optimized_ic_classifier.predict(payload))

# %%
result = json.loads(ic_classifier.predict(payload))

# %%
# the result will output the probabilities for all classes
# find the class with maximum probability and print the class index
index = np.argmax(result)
print("Result: label - " + object_categories[index] + ", probability - " + str(result[index]))

# %% [markdown]
# ## Clean up
#
#
# When we're done with the endpoint, we can just delete it and the backing instances will be released. Uncomment and run the following cell to delete the endpoint and model

# %%
ic_eia.delete_endpoint()
ic_vanilla.delete_endpoint()
optimized_ic_classifier.delete_endpoint()

# %%
# Out:
# ls: cannot access /home/ec2-user/mxnet: No such file or directory

# %%
# !java --version
# Out:
# Unrecognized option: --version
# Error: Could not create the Java Virtual Machine.
# Error: A fatal exception has occurred. Program will exit.
